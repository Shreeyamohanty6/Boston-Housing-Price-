# %% [markdown]
# 1.DATA COLLECTION

# %%
#The Boston Dataset provided in the assignment
import pandas as pd
housing= pd.read_csv("C:/Users/shree/my_env/housing.csv")

# %%
housing.head()
# Out:
#   0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 1 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0    0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00  505 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
#Adding the column names to the CSV file as there was no column names
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
housing = pd.read_csv('C:/Users/shree/my_env/housing.csv', sep='\s+', header=None, names=column_names)

# %%
#Top 5 rows in the dataset
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# 2.DATA PREPROCESSING

# %%
#Housing Info
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
#Summary of each numerical attributes(all attributes are numerical in our dataset)
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Plotting all the features to get insights on the features and to have a visualisation
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Train Test Split( split_train_test is a function which can split the dataset into train test in the given ratio and it will also suffle the rows)

# %%
import numpy as np

def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size= int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
#Te train and test data is splitted 
train_set, test_set = split_train_test(housing, 0.2)
# Out:
# 405

# %%
len(train_set)
# Out:
# 405

# %%
len(test_set)
# Out:
# 101

# %%
housing = train_set.copy()

# %%
corr_matrix = housing.corr()

# %%
#To find the correlation of various features with respect to the median value of the house to find the most important feature 
corr_matrix["MEDV"].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.671189
# ZN         0.400447
# B          0.340064
# DIS        0.272786
# CHAS       0.122868
# CRIM      -0.395833
# AGE       -0.407816
# RAD       -0.408476
# NOX       -0.448645
# TAX       -0.483387
# INDUS     -0.494745
# PTRATIO   -0.526972
# LSTAT     -0.740158
# Name: MEDV, dtype: float64

# %%
#visualise the correlation of feature with each other having positive correlation coefficient
from pandas.plotting import scatter_matrix
attributes = ['MEDV', 'RM', 'ZN', 'B', 'DIS', 'CHAS']
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='B', ylabel='MEDV'>,
#         <Axes: xlabel='DIS', ylabel='MEDV'>,
#         <Axes: xlabel='CHAS', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='B', ylabel='RM'>,
#         <Axes: xlabel='DIS', ylabel='RM'>,
#         <Axes: xlabel='CHAS', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='B', ylabel='ZN'>,
#         <Axes: xlabel='DIS', ylabel='ZN'>,
#         <Axes: xlabel='CHAS', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='B'>,
#         <Axes: xlabel='RM', ylabel='B'>, <Axes: xlabel='ZN', ylabel='B'>,
# ...

# %%
#As RM is the most important feature in determining MEDV we plotted a graph between RM and MEDV.
#We observerd that there is a linear relationship between them.
housing.plot(kind="scatter", x="RM", y="MEDV",alpha=0.5)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
#Separated the features and the output(i.e the median value of the houses)
housing = train_set.drop("MEDV", axis=1)
housing_labels = train_set["MEDV"].copy()

# %% [markdown]
# 3. Model Development (Training and Evaluating Model)

# %%
# Using Linear Rregression the model was evaluated
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(housing, housing_labels)
# Out:
# LinearRegression()

# %%
some_data = housing.iloc[:5]
some_labels = housing_labels.iloc[:5]
print("Predictions:", linear_reg.predict(some_data))
# Out:
# Predictions: [23.02869088 31.93847074 32.06475153 18.12685327 20.70342673]

# %%
 print("Labels:", list(some_labels))
# Out:
# Labels: [21.0, 26.7, 31.1, 20.8, 22.7]

# %%
#Mean Squared Error and Root Mean Squared Error was calculated to evaluate the model's performance
from sklearn.metrics import mean_squared_error
housing_predictions = linear_reg.predict(housing)
linear_mse = mean_squared_error(housing_labels, housing_predictions)
linear_rmse = np.sqrt(linear_mse)
linear_rmse
# Out:
# np.float64(4.62317944753998)

# %%
# Another model (Decision Tree) was used
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing, housing_labels)
# Out:
# DecisionTreeRegressor()

# %%
housing_predictions = tree_reg.predict(housing)
tree_mse = mean_squared_error(housing_labels, housing_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# np.float64(0.0)

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_reg, housing, housing_labels, scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [6.19450976 6.03754513 4.66413404 4.82362074 4.79898363 4.70273856
#  3.8203403  3.8960557  5.23705547 5.26929787]
# Mean: 4.94442812082174
# Standard deviation: 0.7405515064038015

# %%
linear_scores = cross_val_score(linear_reg, housing, housing_labels, scoring="neg_mean_squared_error", cv=10)
linear_rmse_scores = np.sqrt(-linear_scores)
display_scores(linear_rmse_scores)
# Out:
# Scores: [5.98211856 5.18839783 5.27791353 4.10158499 4.50867076 5.31072331
#  4.73643206 3.27785627 5.66919636 4.05521577]
# Mean: 4.810810942314598
# Standard deviation: 0.7899463622283256

# %%
# Random Forest was used as a model
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(housing, housing_labels)
# Out:
# RandomForestRegressor()

# %%
forest_rmse_scores = np.sqrt(-cross_val_score(forest_reg, housing, housing_labels, scoring="neg_mean_squared_error", cv=10))
display_scores(forest_rmse_scores)
# Out:
# Scores: [3.90228577 4.68565022 3.35951507 2.77852868 2.82266988 2.87597621
#  4.42292806 2.75140617 5.08346802 2.55267922]
# Mean: 3.5235107300532666
# Standard deviation: 0.8813335329817127

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [
 {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
 {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
 ]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
 scoring='neg_mean_squared_error',
return_train_score=True)
grid_search.fit(housing, housing_labels)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
final_model = grid_search.best_estimator_
X_test = test_set.drop("MEDV", axis=1)
y_test = test_set["MEDV"].copy()
final_predictions = final_model.predict(X_test)
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
 from scipy import stats
confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1,
loc=squared_errors.mean(),
scale=stats.sem(squared_errors)))
# Out:
# array([2.00915965, 4.7559137 ])

# %% [markdown]
# 4. Model Evaluation

# %%
# Evaluate the model
mse = mean_squared_error(y_test, final_predictions)
rmse = np.sqrt(mse)
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 13.327718811881184
# Root Mean Squared Error: 3.6507148357385

# %%
#Visualise the model
X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = data['MEDV']
plt.figure(figsize=(10, 6))
plt.scatter(y_test, final_predictions, alpha=0.6, color='b', label='Predicted vs Actual')
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', linewidth=2, label='Perfect Prediction')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices')
plt.legend()
plt.show()

# %%
#From the grph we can conclude that our model is working fine and is having a good accuracy.
from sklearn.metrics import mean_squared_error, r2_score
mape = np.mean(np.abs((y_test - final_predictions) / y_test)) * 100

r2 = r2_score(y_test, final_predictions)

print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'R² Score: {r2}')
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
# Out:
# Mean Squared Error: 13.327718811881184
# Root Mean Squared Error: 3.6507148357385
# R² Score: 0.8645412366121495
# Mean Absolute Percentage Error (MAPE): 10.28%
